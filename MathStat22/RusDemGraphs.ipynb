# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
NUM_POP = [float(a.replace(",", ".")) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\demo11.txt").read().split("\n")]
YEARS = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\demo111.txt").read().split("\n")]
plt.figure(figsize=(16,8))
plt.plot(YEARS, NUM_POP, color="red", label="NumOfPop")
#plt.plot(2014, NUM_POP[40], "o", color="black", label="Krim")
#plt.plot(1990, NUM_POP[24], "o", color="orange", label="90e")
plt.title("GenNumOfPop")
plt.xlabel("Year")
plt.ylabel("Num")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7713d3aca0bf> in <module>()
# ----> 1 NUM_POP = [float(a.replace(",", ".")) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\demo11.txt").read().split("\n")]
#       2 YEARS = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\demo111.txt").read().split("\n")]
#       3 plt.figure(figsize=(16,8))
#       4 plt.plot(YEARS, NUM_POP, color="red", label="NumOfPop")
#       5 #plt.plot(2014, NUM_POP[40], "o", color="black", label="Krim")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\LEARN\\NGU\\Economika\\RussianDemography\\demo11.txt'

# %%
POP_V = [float(a.replace(",", "."))*10**6 for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\demo11.txt").read().split()]
POP_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\demo11_Y.txt").read().split()]
BORN_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\demo21_BORN.txt").read().split()]
DIED_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\demo21_DIED.txt").read().split()]
EP_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\demo21_EP.txt").read().split()]
BDEp_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\demo21_Y.txt").read().split()]
SKR_V = [float(a.replace(",", ".")) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\SKR\demo27_SKR.txt").read().split()]
SKR_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\SKR\demo27_Y.txt").read().split()]
POP_progn_RosStat_V_low = [float(a.replace(",", "."))*10**3 for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\progn1_Pop_low.txt").read().split()]
POP_progn_RosStat_V_high = [float(a.replace(",", "."))*10**3 for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\progn1_Pop_high.txt").read().split()]
POP_progn_RosStat_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\progn1_Y.txt").read().split()]
POP_progn_OON_V_low = [float(a.replace(" ", ""))*10**3 for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\demo11_forecastUN_low.txt").read().split("\t")]
POP_progn_OON_V_high = [float(a.replace(" ", ""))*10**3 for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\demo11_forecastUN_high.txt").read().split("\t")]
POP_progn_OON_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Pop\demo11_Y_forecastUN.txt").read().split("\t")]
BORN_progn_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\progn5_BORN.txt").read().split()]
DIED_progn_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\progn5_DIED.txt").read().split()]
EP_progn_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\progn5_EP.txt").read().split()]
BDEp_progn_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\RSEp\progn5_Y.txt").read().split()]
SKR_progn_V_low = [float(a.replace(",", ".")) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\SKR\progn6_SKR_low.txt").read().split()]
SKR_progn_V_high = [float(a.replace(",", ".")) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\SKR\progn6_SKR_high.txt").read().split()]
SKR_progn_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\SKR\progn6_Y.txt").read().split()]
MIGR_V = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Migr\Migr1_V.txt").read().split()]
MIGR_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Migr\Migr1_Y.txt").read().split()]
MIGR_progn_V_low = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Migr\Migr1_V_progn_low.txt").read().split()]
MIGR_progn_V_high = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Migr\Migr1_V_progn_high.txt").read().split()]
MIGR_progn_Y = [int(a) for a in open(r"D:\LEARN\NGU\Economika\RussianDemography\Migr\Migr1_Y_progn.txt").read().split()]

# %%
#Population
plt.figure(figsize=(16,8))
plt.plot(POP_Y, POP_V, color="red", label="Population")
plt.plot(2014, POP_V[POP_Y.index(2014)], "o", color="black", label="Krim")
plt.plot(1991, POP_V[POP_Y.index(1991)], "o", color="orange", label="Raspad SSSR")
plt.plot(2001, POP_V[POP_Y.index(2001)], "o", color="pink", label="Putin")
plt.title("NumOfPop")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Population
plt.figure(figsize=(16,8))
plt.plot(POP_Y[25:], POP_V[25:], color="red", label="Population")
plt.plot(2014, POP_V[POP_Y.index(2014)], "o", color="black", label="Krim")
plt.plot(1991, POP_V[POP_Y.index(1991)], "o", color="orange", label="Raspad SSSR")
plt.plot(2001, POP_V[POP_Y.index(2001)], "o", color="pink", label="Putin")
plt.title("NumOfPop")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Population
plt.figure(figsize=(16,8))
plt.plot(POP_Y[25:], POP_V[25:], color="red", label="Population")
plt.plot(POP_progn_RosStat_Y, POP_progn_RosStat_V_low, color="blue", label="RosStat-low")
plt.plot(POP_progn_RosStat_Y, POP_progn_RosStat_V_high, color="green", label="RosStat-high")
plt.plot(POP_progn_OON_Y, POP_progn_OON_V_low, color="purple", label="OON-high")
plt.plot(POP_progn_OON_Y, POP_progn_OON_V_high, color="magenta", label="OON-low")
plt.plot(2014, POP_V[POP_Y.index(2014)], "o", color="black", label="Krim")
plt.plot(1991, POP_V[POP_Y.index(1991)], "o", color="orange", label="Raspad SSSR")
plt.plot(2001, POP_V[POP_Y.index(2001)], "o", color="pink", label="Putin")
plt.title("NumOfPop")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Population
plt.figure(figsize=(16,8))
plt.plot(POP_Y[25:], POP_V[25:], color="red", label="Population")
plt.plot(POP_progn_RosStat_Y, POP_progn_RosStat_V_low, color="blue", label="RosStat-low")
plt.plot(POP_progn_RosStat_Y, POP_progn_RosStat_V_high, color="green", label="RosStat-high")
plt.plot(POP_progn_OON_Y[:17], POP_progn_OON_V_low[:17], color="purple", label="OON-high")
plt.plot(POP_progn_OON_Y[:17], POP_progn_OON_V_high[:17], color="magenta", label="OON-low")
plt.plot(2014, POP_V[POP_Y.index(2014)], "o", color="black", label="Krim")
plt.plot(1991, POP_V[POP_Y.index(1991)], "o", color="orange", label="Raspad SSSR")
plt.plot(2001, POP_V[POP_Y.index(2001)], "o", color="pink", label="Putin")
plt.title("NumOfPop")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#BDEp
plt.figure(figsize=(16,8))
plt.plot(BDEp_Y, BORN_V, color="red", label="Rodilos'")
plt.plot(BDEp_Y, DIED_V, color="black", label="Umerlo")
plt.plot(BDEp_Y, EP_V, color="green", label="EstestvPrirost")
plt.title("EP")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#BDEp
plt.figure(figsize=(16,8))
plt.plot(BDEp_Y[4:], BORN_V[4:], color="red", label="Rodilos'")
plt.plot(BDEp_Y[4:], DIED_V[4:], color="black", label="Umerlo")
plt.plot(BDEp_Y[4:], EP_V[4:], color="green", label="EstestvPrirost")
plt.plot(BDEp_progn_Y, BORN_progn_V, color="orange", label="Roditsya")
plt.plot(BDEp_progn_Y, DIED_progn_V, color="gray", label="Umret")
plt.plot(BDEp_progn_Y, EP_progn_V, color="blue", label="EstestvPrirostProgn")
plt.title("EP")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#SKR
plt.figure(figsize=(16,8))
plt.plot(SKR_Y, SKR_V, color="red", label="SKR")
plt.plot(SKR_Y, [2.1 for i in range(len(SKR_V))], color="blue", label="SohrPop")
plt.title("SKR")
plt.xlabel("year")
plt.ylabel("detey/1jenshinu")
plt.grid(True)
plt.legend()
plt.show()

# %%
#SKR
plt.figure(figsize=(16,8))
plt.plot(SKR_Y[3:], SKR_V[3:], color="red", label="SKR")
plt.plot(SKR_Y[3:]+SKR_progn_Y, [2.1 for i in range(len(SKR_V[3:])+len(SKR_progn_Y))], color="blue", label="SohrPop")
plt.plot(SKR_progn_Y, SKR_progn_V_high, color="purple", label="SKR-high")
plt.plot(SKR_progn_Y, SKR_progn_V_low, color="magenta", label="SKR-low")
plt.title("SKR")
plt.xlabel("year")
plt.ylabel("detey/1jenshinu")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Migr
plt.figure(figsize=(16,8))
plt.plot(MIGR_Y, MIGR_V, color="green", label="MigrSaldo")
plt.title("Migr")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Migr
plt.figure(figsize=(16,8))
plt.plot(MIGR_Y, MIGR_V, color="green", label="MigrSaldo")
plt.plot(MIGR_progn_Y, MIGR_progn_V_high, color="purple", label="MigrSaldo-high")
plt.plot(MIGR_progn_Y, MIGR_progn_V_low, color="magenta", label="MigrSaldo-low")
plt.title("Migr")
plt.xlabel("year")
plt.ylabel("chelovek")
plt.grid(True)
plt.legend()
plt.show()
